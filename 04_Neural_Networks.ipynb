# %% [markdown]
# <a href="https://colab.research.google.com/github/dilanHewawitharana/TensorFlow-2.0-Self-Learning/blob/main/04_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # this line is not required unless you are in a notebook`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist  # load dataset

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()  # split into tetsing and training

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
train_images[0,23,23]  # let's have a look at one pixel
# Out:
# 194

# %%
train_labels[:10]  # let's have a look at the first 10 training labels
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5], dtype=uint8)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # input layer (1)
    keras.layers.Dense(128, activation='relu'),  # hidden layer (2)
    keras.layers.Dense(10, activation='softmax') # output layer (3)
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)  # we pass the data, labels and epochs and watch the magic!
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6278 - accuracy: 0.7837
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3798 - accuracy: 0.8636
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3347 - accuracy: 0.8787
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3093 - accuracy: 0.8881
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2942 - accuracy: 0.8922
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2737 - accuracy: 0.8980
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2640 - accuracy: 0.9018
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2531 - accuracy: 0.9044
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2474 - accuracy: 0.9093
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=1) 

print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3245 - accuracy: 0.8874
# Test accuracy: 0.8873999714851379

# %%
predictions = model.predict(test_images)

# %%
predictions[2]
# Out:
# array([6.1013264e-11, 1.0000000e+00, 2.4943514e-14, 2.8915001e-11,
#        1.1736418e-13, 1.9121706e-23, 1.9128695e-13, 1.3995735e-28,
#        2.0364790e-14, 1.1071281e-21], dtype=float32)

# %%
np.argmax(predictions[2])
# Out:
# 1

# %%
plt.figure()
plt.imshow(test_images[2])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR

def predict(model, image, correct_label):
  class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
  prediction = model.predict(np.array([image]))
  predicted_class = class_names[np.argmax(prediction)]

  show_image(image, class_names[correct_label], predicted_class)


def show_image(img, label, guess):
  plt.figure()
  plt.imshow(img, cmap=plt.cm.binary)
  plt.title("Excpected: " + label)
  plt.xlabel("Guess: " + guess)
  plt.colorbar()
  plt.grid(False)
  plt.show()

  print("Excpected: {}".format(label))
  print("Guess: {}".format(guess))


def get_number():
  while True:
    num = input("Pick a number: ")
    if num.isdigit():
      num = int(num)
      if 0 <= num <= 1000:
        return int(num)
    else:
      print("Try again...")

#num = get_number()

for num in range(100):
  image = test_images[num]
  label = test_labels[num]
  predict(model, image, label)
# Out:
# Excpected: Ankle boot
# Guess: Ankle boot
# Excpected: Pullover
# Guess: Pullover
# Excpected: Trouser
# Guess: Trouser
# Excpected: Trouser
# Guess: Trouser
# Excpected: Shirt
# Guess: Shirt
# Excpected: Trouser
# Guess: Trouser
# Excpected: Coat
# Guess: Coat
# Excpected: Shirt
# Guess: Shirt
# Excpected: Sandal
# Guess: Sandal
# Excpected: Sneaker
# Guess: Sneaker
# Excpected: Coat
# Guess: Coat
# Excpected: Sandal
# Guess: Sandal
# Excpected: Sneaker
# Guess: Sandal
# Excpected: Dress
# Guess: Dress
# Excpected: Coat
# Guess: Coat
# Excpected: Trouser
# Guess: Trouser
# Excpected: Pullover
# Guess: Pullover
# Excpected: Coat
# Guess: Pullover
# Excpected: Bag
# Guess: Bag
# Excpected: T-shirt/top
# Guess: T-shirt/top
# Excpected: Pullover
# Guess: Pullover
# Excpected: Sandal
# Guess: Sandal
# Excpected: Sneaker
# Guess: Sneaker
# Excpected: Ankle boot
# Guess: Sandal
# Excpected: Trouser
# Guess: Trouser
# Excpected: Coat
# Guess: Pullover
# Excpected: Shirt
# Guess: Shirt
# ...
